# %% [markdown]
# # Домашнее задание "Функции нескольких переменных".

# %% [markdown]
# ## Уровень 0:

# %% [markdown]
# ### Задание 1

# %% [markdown]
# Посчитайте частные производные функций:
#
# 1) $f(x,y)=2x^2y^3 + 1/x + y^2x + 7$
#
# 2) $f(x,y)=x^2y - sin(xy) + cos(x^2) + 6y$

# %%
import sympy as sym
import numpy as np

# %%
x = sym.Symbol('x')
y = sym.Symbol('y')

# %%
func1 = 2*x**2*y**3 + 1/x + y**2*x + 7
func1
# Out:
# 2*x**2*y**3 + x*y**2 + 7 + 1/x

# %%
sym.diff(func1, x)
# Out:
# 4*x*y**3 + y**2 - 1/x**2

# %%
sym.diff(func1, y)
# Out:
# 6*x**2*y**2 + 2*x*y

# %%
func2 = x**2*y - sym.sin(x*y) + sym.cos(x**2) + 6*y
func2
# Out:
# x**2*y + 6*y - sin(x*y) + cos(x**2)

# %%
sym.diff(func2, x)
# Out:
# 2*x*y - 2*x*sin(x**2) - y*cos(x*y)

# %%
sym.diff(func2, y)
# Out:
# x**2 - x*cos(x*y) + 6

# %% [markdown]
# ## Уровень 1:

# %% [markdown]
# ### Задание 2

# %% [markdown]
# Вычислите градиент функции:
#
# $f(x,y)=2x^2y^3 + 1/x + y^2x + 7$
#
# в точке $(1,2)$

# %%
func1
# Out:
# 2*x**2*y**3 + x*y**2 + 7 + 1/x

# %%
np.array([sym.diff(func1, axis).subs(x, 1).subs(y, 2) for axis in [x, y]])
# Out:
# array([35, 28], dtype=object)

# %% [markdown]
# ### Задание 3

# %% [markdown]
# Постройте трехмерный график функции
#
# $f(x)=x_2^2-x_1^2 x_2 + 2 x_1 x_2$

# %%
def func(x1, x2):
    return x2**2 - x1**2*x2 + 2*x1*x2

# %%
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator

fig = plt.figure(figsize=(15,9))
ax = fig.gca(projection='3d')

X = np.arange(-10, 10, 1)
Y = np.arange(-10, 10, 1)
X, Y = np.meshgrid(X, Y)
Z = func(X, Y)

# График поверхности
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm)

# Настройка оси z
ax.zaxis.set_major_locator(LinearLocator(10))

# Цветовая легенда
fig.colorbar(surf, shrink=0.5, aspect=5)

ax.azim = 45

plt.show()
# Out:
# C:\Users\79111\AppData\Local\Temp\ipykernel_8484\1927742877.py:6: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %% [markdown]
# # Домашнее задание "Центральная предельная теорема и статистика".

# %% [markdown]
# ## Задание.

# %% [markdown]
# В этом задании нужно убедиться, что ЦПТ действительно работает.
#
# Создайте случайную величину из [любого выбранного вами распределения](https://docs.scipy.org/doc/scipy/reference/stats.html), для разных значений `n` сгенерируйте 1000 выборок размера `n`. Постройте гистрограммы средних этих выборок и сделайте выводы.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
# %matplotlib inline

# %%
rv = stats.expon(loc=10, scale=1.5)
sample = rv.rvs(size=1000)

# %%
x = np.linspace(0,2,100)
pdf = rv.pdf(x)
plt.hist(sample, density=True, bins=30, label='sample histogram')
plt.plot(x, pdf, label='theoretical pdf', alpha=0.5)
plt.legend()
plt.ylabel('fraction of samples, $f(x)$')
plt.xlabel('$x$')
plt.show()

# %%
means = []

for i in range(9):
    a = []
    for number in range(1000):
        sample = rv.rvs(size=2**(i+1))
        a.append(sample.mean())
    means.append(a)

# %%
fig, axs = plt.subplots(3, 3, figsize=(17, 12))
k = 0

for i1 in range(3):
    for i2 in range(3):
        axs[i1, i2].hist(means[k], bins=30)
        axs[i1, i2].title.set_text('sample of ' + str(2**(k+1)) + ' histogram')
        k += 1

plt.show()

# %% [markdown]
# # Выводы
# 1. На построенных гистограммах видно, что чем меньше размер выборок, тем более гистограмма их средних похожа на исходное экспоненциальное распределение.
# 2. С увеличением размера выборок форма гистограммы средних все более начинает походить на нормальное распределение, что может служить подтверждением ЦПТ.
# 3. Визуально заметно, что изменение формы распределения с ростом размера выборок происходит вокруг почти неизменного пика, находящегося приблизительно около x=11.5
